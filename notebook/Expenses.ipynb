# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
import os
import sys
import pandas as pd

# %%
loader = CSVLoader(file_path="C:\YTRAG\data\Personal_Finance_Dataset.csv")

data = loader.load()

print(data)
# Out:
# [Document(metadata={'source': 'C:\\YTRAG\\data\\Personal_Finance_Dataset.csv', 'row': 0}, page_content='Date: 2020-01-02\nTransaction Description: Score each.\nCategory: Food & Drink\nAmount: 1485.69\nType: Expense'), Document(metadata={'source': 'C:\\YTRAG\\data\\Personal_Finance_Dataset.csv', 'row': 1}, page_content='Date: 2020-01-02\nTransaction Description: Quality throughout.\nCategory: Utilities\nAmount: 1475.58\nType: Expense'), Document(metadata={'source': 'C:\\YTRAG\\data\\Personal_Finance_Dataset.csv', 'row': 2}, page_content='Date: 2020-01-04\nTransaction Description: Instead ahead despite measure ago.\nCategory: Rent\nAmount: 1185.08\nType: Expense'), Document(metadata={'source': 'C:\\YTRAG\\data\\Personal_Finance_Dataset.csv', 'row': 3}, page_content='Date: 2020-01-05\nTransaction Description: Information last everything thank serve.\nCategory: Investment\nAmount: 2291.0\nType: Income'), Document(metadata={'source': 'C:\\YTRAG\\data\\Personal_Finance_Dataset.csv', 'row':
# ...

# %%
loader = CSVLoader(file_path="C:\YTRAG\data\Personal_Finance_Dataset.csv", source_column="Category")

data = loader.load()

print(data)
# Out:
# [Document(metadata={'source': 'Food & Drink', 'row': 0}, page_content='Date: 2020-01-02\nTransaction Description: Score each.\nCategory: Food & Drink\nAmount: 1485.69\nType: Expense'), Document(metadata={'source': 'Utilities', 'row': 1}, page_content='Date: 2020-01-02\nTransaction Description: Quality throughout.\nCategory: Utilities\nAmount: 1475.58\nType: Expense'), Document(metadata={'source': 'Rent', 'row': 2}, page_content='Date: 2020-01-04\nTransaction Description: Instead ahead despite measure ago.\nCategory: Rent\nAmount: 1185.08\nType: Expense'), Document(metadata={'source': 'Investment', 'row': 3}, page_content='Date: 2020-01-05\nTransaction Description: Information last everything thank serve.\nCategory: Investment\nAmount: 2291.0\nType: Income'), Document(metadata={'source': 'Food & Drink', 'row': 4}, page_content='Date: 2020-01-13\nTransaction Description: Future choice whatever from.\nCategory: Food & Drink\nAmount: 1126.88\nType: Expense'), Document(metadata={'source':
# ...

# %%
from langchain_text_splitters import TokenTextSplitter

token_splitter = TokenTextSplitter(chunk_size=10, chunk_overlap=2)

# Split all rows
all_chunks = token_splitter.split_documents(data)

# Inspect first few chunks
for chunk in all_chunks[:10]:
    print(chunk.page_content)
# Out:
# Date: 2020-01-02
# Transaction Description
# Transaction Description: Score each.
# Category: Food
# : Food & Drink
# Amount: 1485.
# 85.69
# Type: Expense
# Date: 2020-01-02
# Transaction Description
# Transaction Description: Quality throughout.
# Category: Utilities
# : Utilities
# Amount: 1475.58
#
# 58
# Type: Expense
# Date: 2020-01-04
# Transaction Description
# Transaction Description: Instead ahead despite measure ago.

# %%
import os
import getpass

if not os.getenv("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("AIzaSyC6lDWb_BfV9vIuFnCNVpgY1eOZN0BG774")

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-001"
)

embeddings.embed_query("test")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[22], line 3
#       1 from langchain_google_genai import GoogleGenerativeAIEmbeddings
# ----> 3 embeddings = GoogleGenerativeAIEmbeddings(
#       4     model="models/gemini-embedding-001"
#       5 )
#       7 embeddings.embed_query("test")
#
# File c:\YTRAG\.venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
# ...

# %%
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS



vectorstore = FAISS.from_documents(docs, embeddings)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\YTRAG\.venv\Lib\site-packages\langchain_google_genai\embeddings.py:432, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     431 try:
# --> 432     result = self.client.models.embed_content(
#     433         model=self.model,
#     434         contents=batch,
#     435         config=config,
#     436     )
#     437 except ClientError as e:
#
# File c:\YTRAG\.venv\Lib\site-packages\google\genai\models.py:4191, in Models.embed_content(self, model, contents, config)
#    4189 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4191 response = self._api_client.request(
#    4192     'post', path, request_dict, http_options
#    4193 )
#    4195 response_dict = {} if not response.body else json.loads(response.body)
#
# ...
